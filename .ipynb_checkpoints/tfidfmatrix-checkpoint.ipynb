# %%
import numpy as np
import pandas as pd 
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import nltk 
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import cross_val_score
from sklearn.metrics.pairwise import euclidean_distances
from collections import defaultdict

# %%
dataset = pd.read_json('300-399.json')
data1 = pd.read_json('400-499.json') 
data2 = pd.read_json('0-200.json')
data3 = pd.read_json('200-299.json')
dataset = dataset.append(data1) 
dataset = dataset.append(data2) 
dataset = dataset.append(data3)

# %%
print (len(dataset.keys()))
# Out:
# 397

# %% [markdown]
# # Dictionary Index

# %%
vectorizer = TfidfVectorizer(stop_words='english' ,
                     binary=False,
                     max_df=0.95, 
                     min_df=0.15,
                     ngram_range = (1,2),use_idf = False, norm = 'l2')

# %%
# create a list of reviews rather than creating a list of list 
#dictionary for each keys 
#need to create it in one list but is not creating in one list 


#key : title #value : string of all 10 reviews in one string 
onlyreviews = defaultdict(str) 
for keys in dataset.keys():
    #keys = keys.encode('UTF8')
    keyreview = ""
    datasets = dataset[keys]['review']
    for i in datasets :  
        if type(i)!= float : 
            for item in i :
                keyreview 
                for k in item: 
    
                    keyreview = keyreview + k 
    keyreview = keyreview.encode('UTF8') 
    keys = keys.encode('UTF8')
    onlyreviews[keys] = keyreview


#for k in onlyreviews["A Book of Common Prayer"] : 
 #   print(k)

# %%
book_array = onlyreviews.keys()

book_to_index= {book : i for i, book in enumerate(book_array)}

index_to_book = {i : book for i, book in enumerate(book_array)}

review_vectors = vectorizer.fit_transform([onlyreviews[keys] for keys in onlyreviews]).toarray()

# %%
#print(review_vectors.shape)

#print(len(vectorizer.vocabulary_))  
#print(review_vectors[0])

#print(vectorizer.get_feature_names()) 
#creating vectorization 
#title and index connect array 
# and words enumerations

# %% [markdown]
# # Cosine Similarity Matrix Using Book Title and similarity Matrix

# %%
#similarity Matrix Creation 
def get_sim(book1, book2, input_doc_mat, book_to_index):
    """Returns a float giving the cosine similarity of 
       the two movie transcripts.
    
    Params: {book1: String,
             book2: String,
             input_doc_mat: Numpy Array,
             movie_to_index: Dict}
    Returns: Float (Cosine similarity of the two movie transcripts.)
    """
    # YOUR CODE HERE

    book1idx = book_to_index[book1] 
    book2idx = book_to_index[book2] 
    
    mat1 = input_doc_mat[book1idx] 
    mat2 = input_doc_mat[book2idx] 
    num = np.dot(mat1, mat2) 
    
    onenorm  = np.sqrt(np.sum(np.square(mat1))) 
    twonorm = np.sqrt(np.sum(np.square(mat2)))  
    
    denum = onenorm * twonorm 
     
    cosine = num/denum
    
    return cosine

# %%
def build_book_sims_cos(n_books,index_to_book,input_doc_mat,book_to_index,input_get_sim_method):
    """Returns a movie_sims matrix of size (num_movies,num_movies) where for (i,j):
        [i,j] should be the cosine similarity between the movie with index i and the movie with index j
        
    Note: What you set the diagonal to doesn't really matter, 
    but you should set it to 1 to indicate that all movies are trivially perfectly similar to themselves.
    
    Params: {n_book: Integer,
             index_to_book: String,
             input_doc_mat: Numpy Array,
             movie_to_index: Dict,
             input_get_sim_method: Function}
    Returns: Numpy Array 
    """
    # YOUR CODE HERE
    #hopefully this is okay! I guess 
    returnarray = np.zeros((n_books, n_books))
    for i in range(n_books) : 
        iname = index_to_book[i]  
        for j in range(i): 
            jname = index_to_book[j] 
            number = input_get_sim_method(iname, jname, input_doc_mat, book_to_index)
            returnarray[i][j] = number 
            returnarray[j][i] = number 
        returnarray[i][i] = 1.0 
    return returnarray

# %%
#create cosine matrix 
num_books = len(index_to_book)
books_list = dataset.keys() 
book_sims_cos = build_book_sims_cos(num_books, index_to_book, review_vectors, book_to_index, get_sim)
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in double_scalars

# %%
#draw the matrix by the matlib 
assert type(book_sims_cos) == np.ndarray
assert book_sims_cos.shape == (397,397)

# %% [markdown]
# # Print top Ten books similar to the given book  reviews

# %%
#similarity measure print top ten that are related to one another 
#top ten similarity of the books related to the books that are given

# %%
#import matplotlib.pyplot as plt

#plt.imshow(book_sims_cos , interpolation='none',
      #     cmap=plt.cm.Greys)
#plt.colorbar()

#plt.xticks(range(num_books),books_list , rotation=90)
#plt.yticks(range(num_books), books_list)
#plt.show()

# %%
def get_ranked_books(book, matrix):
    """
    Return sorted rankings (most to least similar) of movies as 
    a list of two-element tuples, where the first element is the 
    movie name and the second element is the similarity score
    
    Params: {book: String,
             matrix: np.ndarray}
    Returns: List<Tuple>
    """
    
    # Get movie index from movie name
    book_idx = book_to_index[book]
    
    # Get list of similarity scores for movie
    score_lst = matrix[book_idx]
    book_score_lst = [(index_to_book[i], s) for i,s in enumerate(score_lst)]
    
    # Do not account for movie itself in ranking
    book_score_lst = book_score_lst[:book_idx] + book_score_lst[book_idx+1:]
    
    # Sort rankings by score
    book_score_lst = sorted(book_score_lst, key=lambda x: -x[1])
    
    return book_score_lst


def print_top(book, matrix, sim_type, k=10):
    """
    Print the k most and least similar movies to 'star wars'
    
    Params: {book: String,
             matrix: np.ndarray,
             sim_type: String,
             k: Integer}
    Returns: None
    """
    
    book_score_lst = get_ranked_books(book, matrix)
    
    print("Top {} most similar books to {} [{}]".format(k, book , sim_type))
    print("======")
    for (book, score) in book_score_lst[:k]:
        print("%.3f %s" % (score, book))

    print()
    
    print("Top {} least similar books to {} [{}]".format(k, book , sim_type))
    print("======")
    for (book, score) in book_score_lst[-k:][::-1]:
        print("%.3f %s" % (score, book))

# %%
print_top('Harry Potter and the Order of the Phoenix (Harry Potter, #5)', book_sims_cos, 'cosine sim')
# Out:
# Top 10 most similar books to Harry Potter and the Order of the Phoenix (Harry Potter, #5) [cosine sim]
# ======
# 0.518 Dios emperador de Dune (Dune Chronicles, #4)
# 0.517 The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy, #1)
# 0.516 Heretics of Dune (Dune Chronicles #5)
# 0.505 Stranger in a Strange Land
# 0.482 J.R.R. Tolkien 4-Book Boxed Set: The Hobbit and The Lord of the Rings
# 0.481 A Literature Guide [To] The Phantom Tollbooth Written By Norton Juster; Illustrated By Jules Feiffer
# 0.473 The Portrait of a Lady (The Classic Collection)
# 0.473 New Essays on 'The Portrait of a Lady'
# 0.473 Portrait of a Lady
# 0.472 The Silver Sword
# ()
# Top 10 least similar books to The Silver Sword [cosine sim]
# ======
# 0.141 The Inner Life of Martin Frost
# 0.147 Long Shadows: Truth, Lies and History
# 0.171 Timbuktu / Leviathan / Moon Palace
# 0.171 Paul Auster and Postmodern Quest: On the Road to Nowhere
# 0.181 The Red Notebook: True Stories
# 0.196 Love Your Handwriting (Creating Keepsakes)
# 0.196 Simply Beautiful Beaded Jewelry
# 0.196 Active Literacy Across the Curriculum: Strategies for Reading, Writing, Speaking, and Listening
# 0.196 Paul Auster (French Edition)
# 0.201 True Tales of American Life

# %%
# Evaluation Check whether the books exist in the book dictionary 
#book

# %%
book_array = onlyreviews.keys() 
lstofbooks = [u'Child of the Prophecy (Sevenwaters, #3)',
  u'Gregor and the Marks of Secret (Underland Chronicles, #4)',
  u'Emperor Mage (Immortals, #3)',
  u"The Queen of Attolia (The Queen's Thief, #2)",
  u"The Wizard's Dilemma (Young Wizards, #5)",
  u'Awakening (Sweep, #5)',
  u'A Ring of Endless Light (Austin Family, #4)',
  u'A Muralha de Gelo (As Cr\xf3nicas de Gelo e Fogo #2)',
  u'Black Heart (Curse Workers, #3)',
  u'The Indigo Spell (Bloodlines, #3)',
  u'The Atlantis Complex (Artemis Fowl, #7)',
  u"The Demon's Covenant (The Demon's Lexicon, #2)",
  u'Syren (Septimus Heap, #5)',
  u'Haunted (The Mediator, #5)',
  u'The Farthest-Away Mountain',
  u'Dark Whispers (Unicorn Chronicles, #3)',
  u'Curse of the Blue Tattoo: Being an Account of the Misadventures of Jacky Faber, Midshipman and Fine Lady (Bloody Jack, #2)',
  u'The Subtle Knife (His Dark Materials, #2)']  
newlstofbooks = [] 

for k in lstofbooks :  
    newlstofbooks.append(k.encode('UTF8'))

for k in newlstofbooks : 
    if k in book_array : 
        print(True)

# %% [markdown]
# # Cosine Similarity Based on Description

# %%
#description TFIDF Vectorizer 
# create a list of reviews rather than creating a list of list 
#dictionary for each keys 
#need to create it in one list but is not creating in one list 


#key : title #value : string of all 10 reviews in one string 
onlydescription = defaultdict(str) 
for keys in dataset.keys():
    #keys = keys.encode('UTF8')
    #keyreview = ""
    description = dataset[keys]['description']
    
    print(type(description)) 
    #print(type(description )) 
    #print(description)
    print("First Key")
    print(keys)
    print(description) 
    #for i in description : 
       # print(i) 
       # if type(i)!= float :  
            
   # keyreview = ""
   ## datasets = dataset[keys]['review']
   # for i in datasets :  
       
         #   for item in i :
         #       keyreview 
         #       for k in item: 
    
       #             keyreview = keyreview + k 
   # keyreview = keyreview.encode('UTF8') 
   # keys = keys.encode('UTF8')
   # onlyreviews[keys] = keyreview



#for k in onlyreviews["A Book of Common Prayer"] : 
 #   print(k)
# Out:
# <class 'pandas.core.series.Series'>
# First Key
# "A" Is for Zebra
# description    <b>Mark Shulman and Tamara Petrosino return wi...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: "A" Is for Zebra, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# 100 Bullshit Jobs...And How to Get Them
# description    The scholarly discipline of Bullshit Studies h...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: 100 Bullshit Jobs...And How to Get Them, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# 100 Years of Lynchings
# description    Ginzburg compiles vivid newspaper accounts fro...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: 100 Years of Lynchings, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Book of Common Prayer
# description                                                  NaN
# description    Writing with the telegraphic swiftness and mic...
# description                                                  NaN
# description                                                  NaN
# Name: A Book of Common Prayer, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Challenge to the Critics: Scholarly Evidences of the Book of Mormon
# description                                                  NaN
# description                                                  NaN
# description    "A Challenge to the Critics" is a carefully do...
# description                                                  NaN
# Name: A Challenge to the Critics: Scholarly Evidences of the Book of Mormon, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Changeling for All Seasons
# description                                                  NaN
# description                                                  NaN
# description    "A Changeling for All Seasons" Ten unforgettab...
# description                                                  NaN
# Name: A Changeling for All Seasons, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Literature Guide [To] The Phantom Tollbooth Written By Norton Juster; Illustrated By Jules Feiffer
# description    None
# description     NaN
# description     NaN
# description     NaN
# Name: A Literature Guide [To] The Phantom Tollbooth Written By Norton Juster; Illustrated By Jules Feiffer, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Literature Guide to "A Wrinkle in Time" by Madeleine L'Engle
# description     NaN
# description     NaN
# description    None
# description     NaN
# Name: A Literature Guide to "A Wrinkle in Time" by Madeleine L'Engle, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Long Shadow (Inspector Ian Rutledge, #8)
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    "Seamless in its storytelling and enthralling ...
# Name: A Long Shadow (Inspector Ian Rutledge, #8), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Shadow in Summer (Long Price Quartet, #1)
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    The city-state of Saraykeht dominates the Summ...
# Name: A Shadow in Summer (Long Price Quartet, #1), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Short History of Nearly Everything
# description                                                  NaN
# description                                                  NaN
# description    In Bryson's biggest book, he confronts his gre...
# description                                                  NaN
# Name: A Short History of Nearly Everything, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Tomb for Anatole: Poetry
# description                                                  NaN
# description    <em>"One of the most moving accounts of a man ...
# description                                                  NaN
# description                                                  NaN
# Name: A Tomb for Anatole: Poetry, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Treasury of Kahlil Gibran
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    Kahlil Gibran, author of "The Prophet," is kno...
# Name: A Treasury of Kahlil Gibran, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Was Once an Apple Pie
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    Hand painted cut paper artwork by Caldecott wi...
# Name: A Was Once an Apple Pie, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Wrinkle in Time (A Wrinkle in Time Quintet, #1)
# description                                                  NaN
# description                                                  NaN
# description    It was a dark and stormy night; Meg Murry, her...
# description                                                  NaN
# Name: A Wrinkle in Time (A Wrinkle in Time Quintet, #1), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Wrinkle in Time by Madeleine L'Engle: Study Guide
# description                                                  NaN
# description                                                  NaN
# description    On a dark and stormy night, Meg Murry and her ...
# description                                                  NaN
# Name: A Wrinkle in Time by Madeleine L'Engle: Study Guide, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Wrinkle in Time: A Guide for Using "A Wrinkle in Time" in the Classroom
# description                                                  NaN
# description                                                  NaN
# description    This resource is directly related to its liter...
# description                                                  NaN
# Name: A Wrinkle in Time: A Guide for Using "A Wrinkle in Time" in the Classroom, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Wrinkle in Time: A Reading Guide
# description                                                  NaN
# description                                                  NaN
# description    A Wrinkle in Time by Madeline L'Engle is a fav...
# description                                                  NaN
# Name: A Wrinkle in Time: A Reading Guide, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Wrinkle in Time: L-I-T Guide
# description     NaN
# description     NaN
# description    None
# description     NaN
# Name: A Wrinkle in Time: L-I-T Guide, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Wrinkle in Time: LitPlan Teacher Pack
# description                                                  NaN
# description                                                  NaN
# description    Complete lesson plans for teaching L'Engle's "...
# description                                                  NaN
# Name: A Wrinkle in Time: LitPlan Teacher Pack, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Wrinkle in Time: Teacher Guide
# description                                                  NaN
# description                                                  NaN
# description    This time-saving, easy-to-use teacher guide in...
# description                                                  NaN
# Name: A Wrinkle in Time: Teacher Guide, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Wrinkle in Time: Teaching Unit
# description                                                  NaN
# description                                                  NaN
# description    <i>A Wrinkle in Time</i>, by Madeleine L'Engle...
# description                                                  NaN
# Name: A Wrinkle in Time: Teaching Unit, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A Wrinkle in Time: With Related Readings (A Wrinkle in Time Quintet #1)
# description                                                  NaN
# description                                                  NaN
# description    Now, 40 years after A Wrinkle in Time was firs...
# description                                                  NaN
# Name: A Wrinkle in Time: With Related Readings (A Wrinkle in Time Quintet #1), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# A. Lincoln'S Gettysburg Addres
# description    A unique look at the issues Lincoln struggled ...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: A. Lincoln'S Gettysburg Addres, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Access to Literature: A Wrinkle in Time
# description     NaN
# description     NaN
# description    None
# description     NaN
# Name: Access to Literature: A Wrinkle in Time, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Active Literacy Across the Curriculum: Strategies for Reading, Writing, Speaking, and Listening
# description                                                  NaN
# description                                                  NaN
# description    Highly acclaimed author Heidi Hayes Jacobs sho...
# description                                                  NaN
# Name: Active Literacy Across the Curriculum: Strategies for Reading, Writing, Speaking, and Listening, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Against the Day
# description                                                  NaN
# description    Spanning the period between the Chicago World'...
# description                                                  NaN
# description                                                  NaN
# Name: Against the Day, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Agile Web Development with Rails: A Pragmatic Guide
# description                                                  NaN
# description                                                  NaN
# description    Rails is a full-stack, open source web framewo...
# description                                                  NaN
# Name: Agile Web Development with Rails: A Pragmatic Guide, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# All My Tomorrows (The Orphan Trains Trilogy, #2)
# description                                                  NaN
# description    When 62 orphans and abandoned children leave N...
# description                                                  NaN
# description                                                  NaN
# Name: All My Tomorrows (The Orphan Trains Trilogy, #2), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Along The Clipper Way
# description     NaN
# description    None
# description     NaN
# description     NaN
# Name: Along The Clipper Way, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Always Enough: God's Miraculous Provision Among the Poorest Children on Earth
# description                                                  NaN
# description                                                  NaN
# description    Even the most desperate poverty, the most deva...
# description                                                  NaN
# Name: Always Enough: God's Miraculous Provision Among the Poorest Children on Earth, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Amazons
# description                                                  NaN
# description    This book was written by Don DeLillo under the...
# description                                                  NaN
# description                                                  NaN
# Name: Amazons, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Amazons: An Intimate Memoir by the First Woman Ever to Play in the National Hockey League
# description                                                  NaN
# description    This book was written by Don DeLillo under the...
# description                                                  NaN
# description                                                  NaN
# Name: Amazons: An Intimate Memoir by the First Woman Ever to Play in the National Hockey League, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Americana
# description                                                  NaN
# description    "<i>Nearly every sentence of</i> Americana <i>...
# description                                                  NaN
# description                                                  NaN
# Name: Americana, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# An Art of Desire: Reading Paul Auster
# description                                                  NaN
# description    <i>An Art of Desire. Reading Paul Auster</i> t...
# description                                                  NaN
# description                                                  NaN
# Name: An Art of Desire: Reading Paul Auster, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# An Edward Lear Alphabet
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    Edward Lear's acrobatic rhymes insistently tum...
# Name: An Edward Lear Alphabet, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Anna Karenina
# description                                                  NaN
# description                                                  NaN
# description    Anna Karenina is the wife of a prominant Russi...
# description                                                  NaN
# Name: Anna Karenina, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Anna Karenina
# description                                                  NaN
# description                                                  NaN
# description    Married to a powerful government minister, Ann...
# description                                                  NaN
# Name: Anna Karenina , dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Annals of the Former World
# description                                                  NaN
# description                                                  NaN
# description    The Pulitzer Prize-winning view of the contine...
# description                                                  NaN
# Name: Annals of the Former World, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Another Bullshit Night in Suck City
# description    Nick Flynn met his father when he was working ...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Another Bullshit Night in Suck City, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Armageddon Averted: The Soviet Collapse, 1970-2000
# description                                                  NaN
# description    In the Cold War era that dominated the second ...
# description                                                  NaN
# description                                                  NaN
# Name: Armageddon Averted: The Soviet Collapse, 1970-2000, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Art for Public Places: Critical Essays
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    Information concerning the context of public a...
# Name: Art for Public Places: Critical Essays, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Artesia: Adventures in the Known World
# description                                                  NaN
# description                                                  NaN
# description    The award-winning graphic novel Artesia comes ...
# description                                                  NaN
# Name: Artesia: Adventures in the Known World, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Auggie Wren's Christmas Story
# description                                                  NaN
# description    <b>A timeless, utterly charming Christmas fabl...
# description                                                  NaN
# description                                                  NaN
# Name: Auggie Wren's Christmas Story, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Been Down So Long it Looks Like Up to Me
# description                                                  NaN
# description    Fariña evokes the Sixties as precisely, wittil...
# description                                                  NaN
# description                                                  NaN
# Name: Been Down So Long it Looks Like Up to Me, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Behavior in Public Places
# description     NaN
# description     NaN
# description     NaN
# description    None
# Name: Behavior in Public Places, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Beyond the Red Notebook
# description                                                  NaN
# description    The novels of Paul Auster--finely wrought, sel...
# description                                                  NaN
# description                                                  NaN
# Name: Beyond the Red Notebook, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Big Sur and the Oranges of Hieronymus Bosch
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    Whence Henry Miller's title for this, one of h...
# Name: Big Sur and the Oranges of Hieronymus Bosch, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Bill Bryson's African Diary
# description                                                  NaN
# description                                                  NaN
# description    In the early fall of 2002, famed travel Writer...
# description                                                  NaN
# Name: Bill Bryson's African Diary, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Bowling Alone: The Collapse and Revival of American Community
# description                                                  NaN
# description    Once we bowled in leagues, usually after work-...
# description                                                  NaN
# description                                                  NaN
# Name: Bowling Alone: The Collapse and Revival of American Community, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Bryson's Dictionary of Troublesome Words: A Writer's Guide to Getting It Right
# description                                                  NaN
# description                                                  NaN
# description    A revised and updated edition of a humorous pr...
# description                                                  NaN
# Name: Bryson's Dictionary of Troublesome Words: A Writer's Guide to Getting It Right, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Bucaneer
# description     NaN
# description     NaN
# description    None
# description     NaN
# Name: Bucaneer, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Bullets, Badges, and Bullshit
# description    Bullets, Badges, and Bullshit is a thirty-year...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Bullets, Badges, and Bullshit, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Bullshit Artist: The 9/11 Leadership Myth
# description    No Conspiracy Theories in This Book-Just a Tru...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Bullshit Artist: The 9/11 Leadership Myth, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Camp Cooking: 100 Years The National Museum of Forest Service History
# description    The National Museum of Forest Service History ...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Camp Cooking: 100 Years The National Museum of Forest Service History, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Changeling (Changeling, #1)
# description                                                  NaN
# description                                                  NaN
# description    Neef is a changeling, a human baby stolen by f...
# description                                                  NaN
# Name: Changeling (Changeling, #1), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Changelings (The Twins of Petaybee, #1)
# description                                                  NaN
# description                                                  NaN
# description    With three acclaimed novels – Powers That Be, ...
# description                                                  NaN
# Name: Changelings (The Twins of Petaybee, #1), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Chapterhouse: Dune (Dune Chronicles #6)
# description                                                  NaN
# description                                                  NaN
# description    The desert planet Arrakis, called Dune, has be...
# description                                                  NaN
# Name: Chapterhouse: Dune (Dune Chronicles #6), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Charles Willeford Omnibus: Pick Up/Burnt Orange Heresy/Cockfighter
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    A collection of three Charles Willeford thrill...
# Name: Charles Willeford Omnibus: Pick Up/Burnt Orange Heresy/Cockfighter , dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Chess for Zebras
# description    Jonathan Rowson, author of the highly acclaime...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Chess for Zebras, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Children of Dune (Dune Chronicles #3)
# description                                                  NaN
# description                                                  NaN
# description    The desert planet of Arrakis has begun to grow...
# description                                                  NaN
# Name: Children of Dune (Dune Chronicles #3), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Cien años de soledad
# description    Cien años de soledad ,convertida en poco tiemp...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Cien años de soledad, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Cinnamon and Roses (Rose Trilogy, #1)
# description                                                  NaN
# description                                                  NaN
# description    A plain, hardworking seamstress, Rebecca had n...
# description                                                  NaN
# Name: Cinnamon and Roses (Rose Trilogy, #1), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# City of Glass (The New York Trilogy, #1)
# description                                                  NaN
# description    Nominated for an Edgar award for best mystery ...
# description                                                  NaN
# description                                                  NaN
# Name: City of Glass (The New York Trilogy, #1), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Cliffs Notes on Garcia Marquez' 100 Hundred Years of Solitude
# description    None
# description     NaN
# description     NaN
# description     NaN
# Name: Cliffs Notes on Garcia Marquez' 100 Hundred Years of Solitude, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Cliffs Notes on Stevenson's Treasure Island and Kidnapped
# description    These novels of pirates on the high seas and i...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Cliffs Notes on Stevenson's Treasure Island and Kidnapped, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# CliffsNotes on Tolstoy's Anna Karenina
# description                                                  NaN
# description                                                  NaN
# description    The original CliffsNotes study guides offer ex...
# description                                                  NaN
# Name: CliffsNotes on Tolstoy's Anna Karenina, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Cockfighter
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    The sport is cockfighting and Frank Mansfield ...
# Name: Cockfighter, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Collapse of Burning Buildings: A Guide to Fireground Safety
# description     NaN
# description    None
# description     NaN
# description     NaN
# Name: Collapse of Burning Buildings: A Guide to Fireground Safety, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Collapse: How Societies Choose to Fail or Succeed
# description                                                  NaN
# description    Brilliant, illuminating, and immensely absorbi...
# description                                                  NaN
# description                                                  NaN
# Name: Collapse: How Societies Choose to Fail or Succeed, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Collected Poems
# description                                                  NaN
# description    Paul Auster's penetrating and charged verse re...
# description                                                  NaN
# description                                                  NaN
# Name: Collected Poems, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Colorado Springs Notes, 1899-1900
# description                                                  NaN
# description    His research diary. It reveals his mind during...
# description                                                  NaN
# description                                                  NaN
# Name: Colorado Springs Notes, 1899-1900, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Comedy after Postmodernism: Rereading Comedy from Edward Lear to Charles Willeford
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    Is comedy postmodern?Kirby Olson posits that n...
# Name: Comedy after Postmodernism: Rereading Comedy from Edward Lear to Charles Willeford, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Coming into the Country
# description                                                  NaN
# description                                                  NaN
# description    This is the story of Alaska and the Alaskans. ...
# description                                                  NaN
# Name: Coming into the Country, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Cooking with Fernet Branca (Gerald Samper, #1)
# description                                                  NaN
# description                                                  NaN
# description    Gerald Samper, an effete English snob, has his...
# description                                                  NaN
# Name: Cooking with Fernet Branca (Gerald Samper, #1), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Cosmopolis
# description                                                  NaN
# description    It is an April day in the year 2000 and an era...
# description                                                  NaN
# description                                                  NaN
# Name: Cosmopolis, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Craniosacral Therapy II: Beyond the Dura
# description     NaN
# description     NaN
# description     NaN
# description    None
# Name: Craniosacral Therapy II: Beyond the Dura, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Dalit: The Black Untouchables of India
# description                                                  NaN
# description                                                  NaN
# description    After Centuries of slavery, apartheid and ethn...
# description                                                  NaN
# Name: Dalit: The Black Untouchables of India, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Daniel Deronda
# description    George Eliot’s final novel and her most ambiti...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Daniel Deronda, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Daniel Deronda Notebooks
# description    George Eliot's notebooks from the years 1872-7...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Daniel Deronda Notebooks, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Daniel Deronda, V1
# description    Excerpt from Daniel Deronda, Vol. 1 <br />But ...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Daniel Deronda, V1, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Daniel Deronda: A Conversation
# description    None
# description     NaN
# description     NaN
# description     NaN
# Name: Daniel Deronda: A Conversation, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Decision & Responsibility: A Wrinkle in Time
# description     NaN
# description     NaN
# description    None
# description     NaN
# Name: Decision & Responsibility: A Wrinkle in Time, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Democracy
# description                                                  NaN
# description    Inez Victor knows that the major casualty of t...
# description                                                  NaN
# description                                                  NaN
# Name: Democracy, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Destroy, She Said
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    In this classic novel by the best-selling auth...
# Name: Destroy, She Said, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Dictionary of Bullshit
# description    Bull shit (n.; adj; adv.; etc.)<br />1: deceit...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Dictionary of Bullshit, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Dinner with Anna Karenina
# description     NaN
# description     NaN
# description    None
# description     NaN
# Name: Dinner with Anna Karenina, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Dios emperador de Dune (Dune Chronicles, #4)
# description                                                  NaN
# description                                                  NaN
# description    Esta cuarta entrega de la saga Dune centra su ...
# description                                                  NaN
# Name: Dios emperador de Dune (Dune Chronicles, #4), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Dirk Gently's Holistic Detective Agency (Dirk Gently #1)
# description    What do a dead cat, a computer whiz-kid, an El...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Dirk Gently's Holistic Detective Agency (Dirk Gently #1), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Disappearances
# description                                                  NaN
# description    Beginning with the short fragments of "Spokes"...
# description                                                  NaN
# description                                                  NaN
# Name: Disappearances, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Disney: The First 100 Years
# description    Celebrate the birth, development, and success ...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Disney: The First 100 Years, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Don DeLillo's White Noise (Bloom's Modern Critical Interpretations)
# description                                                  NaN
# description    - Presents the most important 20th-century cri...
# description                                                  NaN
# description                                                  NaN
# Name: Don DeLillo's White Noise (Bloom's Modern Critical Interpretations), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Douglas Adams Starship Titanic: The Official Strategy Guide
# description    None
# description     NaN
# description     NaN
# description     NaN
# Name: Douglas Adams Starship Titanic: The Official Strategy Guide, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Dreamer of Dune: The Biography of Frank Herbert
# description                                                  NaN
# description                                                  NaN
# description    <b>Everyone knows Frank Herbert's Dune.</b><br...
# description                                                  NaN
# Name: Dreamer of Dune: The Biography of Frank Herbert, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Dune (Dune Chronicles, #1)
# description                                                  NaN
# description                                                  NaN
# description    Set in the far future amidst a sprawling feuda...
# description                                                  NaN
# Name: Dune (Dune Chronicles, #1), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Dune Messiah (Dune Chronicles #2)
# description                                                  NaN
# description                                                  NaN
# description    <b>Dune Messiah</b> continues the story of the...
# description                                                  NaN
# Name: Dune Messiah (Dune Chronicles #2), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Dune Trilogy Box Set (Dune Chronicles, #1-3)
# description                                                  NaN
# description                                                  NaN
# description    Dune Trilogy Box Set: Dune, Dune Messiah, Chil...
# description                                                  NaN
# Name: Dune Trilogy Box Set (Dune Chronicles, #1-3), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Edward Lear's Nonsense Verse
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    A delightful picture book for young children, ...
# Name: Edward Lear's Nonsense Verse, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# El Siglo del Espiritu Santo
# description    SPANISH EDITION. The amazing growth of the Pen...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: El Siglo del Espiritu Santo, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# El hacha
# description                                                  NaN
# description                                                  NaN
# description    Brian viaja en una avioneta como único pasajer...
# description                                                  NaN
# Name: El hacha, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# El libro de las ilusiones
# description                                                  NaN
# description    David Zimmer, un escritor y profesor de litera...
# description                                                  NaN
# description                                                  NaN
# Name: El libro de las ilusiones, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Empress in the Wrinkle of Time: The Knight-King Chronicle
# description                                                  NaN
# description                                                  NaN
# description    Tai'sonn Donsibi is a cyborg, an empress of a ...
# description                                                  NaN
# Name: Empress in the Wrinkle of Time: The Knight-King Chronicle, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Essence and Alchemy: A Book of Perfume
# description    An artisan perfumer reveals a lost art and its...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Essence and Alchemy: A Book of Perfume, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Essential Jazz: The First 100 Years (with CD-ROM)
# description    A complete jazz chronology, ESSENTIAL JAZZ: TH...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Essential Jazz: The First 100 Years (with CD-ROM), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Flight: 100 Years of Aviation
# description    From the early pioneers to the latest spacefli...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Flight: 100 Years of Aviation, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# George Eliot and Judaism: An Attempt to Appreciate 'Daniel Deronda'
# description    Subtitled "An Attempt to Appreciate Daniel Der...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: George Eliot and Judaism: An Attempt to Appreciate 'Daniel Deronda', dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Getting Results with Curriculum Mapping
# description                                                  NaN
# description                                                  NaN
# description    Curriculum mapping is said to remove the clutt...
# description                                                  NaN
# Name: Getting Results with Curriculum Mapping, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Ghosts (The New York Trilogy, #2)
# description                                                  NaN
# description    The second book in the acclaimed New York Tril...
# description                                                  NaN
# description                                                  NaN
# Name: Ghosts (The New York Trilogy, #2), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Giving Good Weight
# description                                                  NaN
# description                                                  NaN
# description    "You people come into the market—the Greenmark...
# description                                                  NaN
# Name: Giving Good Weight, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# God Emperor of Dune (Dune Chronicles, #4)
# description                                                  NaN
# description                                                  NaN
# description    Centuries have passed on Dune, and the planet ...
# description                                                  NaN
# Name: God Emperor of Dune (Dune Chronicles, #4), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Gravity's Rainbow
# description                                                  NaN
# description    Winner of the 1973 National Book Award, Gravit...
# description                                                  NaN
# description                                                  NaN
# Name: Gravity's Rainbow, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Great Jones Street
# description                                                  NaN
# description    A troubling satire of the romantic myth of sta...
# description                                                  NaN
# description                                                  NaN
# Name: Great Jones Street, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Growing Up Untouchable in India: A Dalit Autobiography
# description                                                  NaN
# description                                                  NaN
# description    There is much in Vasant Moon's story of his va...
# description                                                  NaN
# Name: Growing Up Untouchable in India: A Dalit Autobiography, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Guts: The True Stories behind Hatchet and the Brian Books
# description                                                  NaN
# description                                                  NaN
# description    Guess what -- Gary Paulsen was being kind to B...
# description                                                  NaN
# Name: Guts: The True Stories behind Hatchet and the Brian Books, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Harry Potter Boxed Set, Books 1-5 (Harry Potter, #1-5)
# description                                                  NaN
# description                                                  NaN
# description    Box Set containing Harry Potter and the Sorcer...
# description                                                  NaN
# Name: Harry Potter Boxed Set, Books 1-5 (Harry Potter, #1-5), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Harry Potter Collection (Harry Potter, #1-6)
# description                                                  NaN
# description                                                  NaN
# description    Six years of magic, adventure, and mystery mak...
# description                                                  NaN
# Name: Harry Potter Collection (Harry Potter, #1-6), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Harry Potter and the Chamber of Secrets (Harry Potter, #2)
# description                                                  NaN
# description                                                  NaN
# description    The Dursleys were so mean and hideous that sum...
# description                                                  NaN
# Name: Harry Potter and the Chamber of Secrets (Harry Potter, #2), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Harry Potter and the Goblet of Fire (Harry Potter, #4)
# description                                                  NaN
# description                                                  NaN
# description    Harry Potter is midway through his training as...
# description                                                  NaN
# Name: Harry Potter and the Goblet of Fire (Harry Potter, #4), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Harry Potter and the Half-Blood Prince (Harry Potter, #6)
# description                                                  NaN
# description                                                  NaN
# description    When Harry Potter and the Half-Blood Prince op...
# description                                                  NaN
# Name: Harry Potter and the Half-Blood Prince (Harry Potter, #6), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Harry Potter and the Order of the Phoenix (Harry Potter, #5)
# description                                                  NaN
# description                                                  NaN
# description    Harry Potter and the Order of the Phoenix is t...
# description                                                  NaN
# Name: Harry Potter and the Order of the Phoenix (Harry Potter, #5), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)
# description                                                  NaN
# description                                                  NaN
# description    Harry Potter's third year at Hogwarts is full ...
# description                                                  NaN
# Name: Harry Potter and the Prisoner of Azkaban (Harry Potter, #3), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Harry Potter and the Sorcerer's Stone (Harry Potter, #1)
# description                                                  NaN
# description                                                  NaN
# description    Harry Potter's life is miserable. His parents ...
# description                                                  NaN
# Name: Harry Potter and the Sorcerer's Stone (Harry Potter, #1), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Hatchet
# description                                                  NaN
# description                                                  NaN
# description    Brian is on his way to Canada to visit his est...
# description                                                  NaN
# Name: Hatchet, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Hatchet Jobs: Writings on Contemporary Fiction
# description                                                  NaN
# description                                                  NaN
# description    Since the initial publication of <i>Hatchet Jo...
# description                                                  NaN
# Name: Hatchet Jobs: Writings on Contemporary Fiction, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Hatchet: A Guide for Using "Hatchet" in the Classroom
# ...
# <class 'pandas.core.series.Series'>
# First Key
# Travels in the Scriptorium
# description                                                  NaN
# description    <div>\n  <div>\n    <b>A man pieces together c...
# description                                                  NaN
# description                                                  NaN
# Name: Travels in the Scriptorium, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Treasure Island
# description    Perhaps Stevenson's best-known work, this adve...
# description                                                  NaN
# description                                                  NaN
# description    Jim Hawkins has led an ordinary life as an inn...
# Name: Treasure Island, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Treasure Island (Great Illustrated Classics)
# description    For generations, readers have enjoyed classic ...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Treasure Island (Great Illustrated Classics), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Tropic of Cancer
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    Now hailed as an American classic, <i>Tropic o...
# Name: Tropic of Cancer, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Tropic of Capricorn
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    Banned in America for almost thirty years beca...
# Name: Tropic of Capricorn, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# True Tales of American Life
# description                                                  NaN
# description    Chosen by Paul Auster out of the four thousand...
# description                                                  NaN
# description                                                  NaN
# Name: True Tales of American Life, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Un raccourci dans le temps
# description                                                  NaN
# description                                                  NaN
# description    Meg Murry ne dort pas cette nuit.<br /><br />D...
# description                                                  NaN
# Name: Un raccourci dans le temps, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Una arruga en el tiempo – A Wrinkle in Time
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    Meg, su hermano y un amigo reciben la visita d...
# Name: Una arruga en el tiempo – A Wrinkle in Time, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Unauthorized Harry Potter Book Seven News: "Half-Blood Prince" Analysis and Speculation
# description                                                  NaN
# description                                                  NaN
# description    Through the magic of print-on-demand technolog...
# description                                                  NaN
# Name: Unauthorized Harry Potter Book Seven News: "Half-Blood Prince" Analysis and Speculation, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Uncommon Carriers
# description                                                  NaN
# description                                                  NaN
# description    <b>What John McPhee's books all have in common...
# description                                                  NaN
# Name: Uncommon Carriers, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Untouchable
# description                                                  NaN
# description                                                  NaN
# description    Bakha is a young man, proud and even attractiv...
# description                                                  NaN
# Name: Untouchable, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Untouchables: My Family's Triumphant Journey Out of the Caste System in Modern India
# description                                                  NaN
# description                                                  NaN
# description    Every sixth human being in the world today is ...
# description                                                  NaN
# Name: Untouchables: My Family's Triumphant Journey Out of the Caste System in Modern India, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# V.
# description                                                  NaN
# description    The wild, macabre tale of the twentieth centur...
# description                                                  NaN
# description                                                  NaN
# Name: V., dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Velvet: A Novel of Suspense
# description    Hank Easton's former lover doesn't hesitate to...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Velvet: A Novel of Suspense, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Vicksburg's Long Shadow: The Civil War Legacy of Race and Remembrance
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    During the hottest days of the summer of 1863,...
# Name: Vicksburg's Long Shadow: The Civil War Legacy of Race and Remembrance, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Vineland
# description                                                  NaN
# description    Vineland, a zone of blessed anarchy in norther...
# description                                                  NaN
# description                                                  NaN
# Name: Vineland, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Vintage Didion
# description                                                  NaN
# description    Joan Didion's unblinking eye and razor-sharp p...
# description                                                  NaN
# description                                                  NaN
# Name: Vintage Didion  , dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# We Tell Ourselves Stories in Order to Live: Collected Nonfiction
# description                                                  NaN
# description    (Book Jacket Status: Jacketed)<br /><br />Joan...
# description                                                  NaN
# description                                                  NaN
# Name: We Tell Ourselves Stories in Order to Live: Collected Nonfiction, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# What If the Zebras Lost Their Stripes?
# description    If the zebras lost their stripes and became di...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: What If the Zebras Lost Their Stripes?, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# What to Expect the First Year (What to Expect)
# description                                                  NaN
# description                                                  NaN
# description    Some things about babies, happily, will never ...
# description                                                  NaN
# Name: What to Expect the First Year (What to Expect), dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# What to Sell on ebay and Where to Get It: The Definitive Guide to Product Sourcing for eBay and Beyond
# description                                                  NaN
# description                                                  NaN
# description    If you want to build a profitable--and consist...
# description                                                  NaN
# Name: What to Sell on ebay and Where to Get It: The Definitive Guide to Product Sourcing for eBay and Beyond, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Where I Was From
# description                                                  NaN
# description    In her moving and insightful new book, Joan Di...
# description                                                  NaN
# description                                                  NaN
# Name: Where I Was From, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Why Write?
# description     NaN
# description    None
# description     NaN
# description     NaN
# Name: Why Write?, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Why Zebras Don't Get Ulcers
# description    A Guide to Stress, Stress-Related Diseases, an...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Why Zebras Don't Get Ulcers, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Wild Wives
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    Jake Blake is a private detective short on cas...
# Name: Wild Wives, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Wish You Were Here: The Official Biography of Douglas Adams
# description    It all started when Douglas Adams demolished p...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Wish You Were Here: The Official Biography of Douglas Adams, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Wizard: The Life and Times of Nikola Tesla: Biography of a Genius
# description                                                  NaN
# description    Nikola Tesla (1856-1943), credited as the insp...
# description                                                  NaN
# description                                                  NaN
# Name: Wizard: The Life and Times of Nikola Tesla: Biography of a Genius, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Wonderful World of Collecting Perfume Bottles: Identification & Value Guide
# description    The Wonderful World of Collecting Perfume Bott...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Wonderful World of Collecting Perfume Bottles: Identification & Value Guide, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# World that is the Book: Paul Auster�s Fiction
# description                                                  NaN
# description    <i>The World that is the Book</i> offers an in...
# description                                                  NaN
# description                                                  NaN
# Name: World that is the Book: Paul Auster�s Fiction, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Worlds Beyond Dune Box
# description                                                  NaN
# description                                                  NaN
# description    Worlds Beyond Dune Box: The Eyes of Heisenberg...
# description                                                  NaN
# Name: Worlds Beyond Dune Box, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Wrinkles in Time
# description                                                  NaN
# description                                                  NaN
# description    In April 1992, a discovery was made that chang...
# description                                                  NaN
# Name: Wrinkles in Time, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Wrinkles in Time: Imprint of Creation
# description                                                  NaN
# description                                                  NaN
# description    In April 1992, a discovery was made that chang...
# description                                                  NaN
# Name: Wrinkles in Time: Imprint of Creation, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Writing
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# description    Written in the splendid bareness of her late s...
# Name: Writing, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Your Call Is Important to Us: The Truth About Bullshit
# description    “There is so much bullshit that one hardly kno...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Your Call Is Important to Us: The Truth About Bullshit, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# Ziggy the Zebra
# description    A parrot has colorful feathers, a crocodile ha...
# description                                                  NaN
# description                                                  NaN
# description                                                  NaN
# Name: Ziggy the Zebra, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# eBay Business All-in-One Desk Reference for Dummies
# description                                                  NaN
# description                                                  NaN
# description    Bestselling author Marsha Collier presents rea...
# description                                                  NaN
# Name: eBay Business All-in-One Desk Reference for Dummies, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# eBay PowerSeller Secrets: Insider Tips from eBay's Most Successful Sellers
# description                                                  NaN
# description                                                  NaN
# description    Offers user tips for serious eBayer, sharing t...
# description                                                  NaN
# Name: eBay PowerSeller Secrets: Insider Tips from eBay's Most Successful Sellers, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# eBay for Dummies
# description                                                  NaN
# description                                                  NaN
# description    Thinking about buying or selling items on eBay...
# description                                                  NaN
# Name: eBay for Dummies, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# eBay: Top 100 Simplified Tips & Tricks
# description                                                  NaN
# description                                                  NaN
# description    You already know eBay basics. Now you'd like t...
# description                                                  NaN
# Name: eBay: Top 100 Simplified Tips & Tricks, dtype: object
# <class 'pandas.core.series.Series'>
# First Key
# ebay Timesaving Techniques for Dummies
# description                                                  NaN
# description                                                  NaN
# description    So, you've gotten started on eBay. You've made...
# description                                                  NaN
# Name: ebay Timesaving Techniques for Dummies, dtype: object
